# %%
#change all images in a directory into jpgs
import pillow_avif
import os
from PIL import Image
import glob
import numpy as np

def get_files(path):
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

#change all images in a directory into jpgs
def convert_to_jpg(path):
    i = 0
    for file in get_files(path):
        print("/"+file)
        print(file[:-4])
        im = Image.open(path + file)
        rgb_im = im.convert('RGB')
        rgb_im.save(str(i) +'.jpg')
        i += 1

# %%
# convert all images in the ALL directory to jpgs
convert_to_jpg('C:\\Users\\thoma\\Documents\\Github\\FoocusLogoDataset\\AALL\\')
# Out:
# /001c3286-1440.jpg
# 001c3286-1440
# /00651efd-dd9c-439b-8e18-11b5687e89e4.avif
# 00651efd-dd9c-439b-8e18-11b5687e89e4.
# /018a9616-5ebe-48ad-b22a-11b1dbff394d.avif
# 018a9616-5ebe-48ad-b22a-11b1dbff394d.
# /02806.jpg
# 02806
# /04899.jpg
# 04899
# /0535a461-54a7-4e30-9c78-e1e5d2ec35a8.avif
# 0535a461-54a7-4e30-9c78-e1e5d2ec35a8.
# /05b27224-184d-4e36-8f0e-992f0dd5c244.avif
# 05b27224-184d-4e36-8f0e-992f0dd5c244.
# /05c5765b-e51f-463e-b2ec-c9ec651e190b.avif
# 05c5765b-e51f-463e-b2ec-c9ec651e190b.
# /0619.jpg
# 0619
# /06208.jpg
# 06208
# /07BEA768-6B33-4123-84EA-DF0B1F522955.jpeg.jpg
# 07BEA768-6B33-4123-84EA-DF0B1F522955.jpeg
# /090123+ta_+S08-trening_0147.jpg
# 090123+ta_+S08-trening_0147
# /09cdb3ee-ffba-4117-99d9-b6c0be5cde07.avif
# 09cdb3ee-ffba-4117-99d9-b6c0be5cde07.
# /0a924df9-97a0-4c65-9085-2eafeb47a5df.avif
# 0a924df9-97a0-4c65-9085-2eafeb47a5df.
# /0b4a0882-bf12-4b98-800a-2ab631045287.avif
# 0b4a0882-bf12-4b98-800a-2ab631045287.
# ...
